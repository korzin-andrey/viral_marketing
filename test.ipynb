# %%
import matplotlib.pyplot as plt

from simulation.sir import SIRModel
from simulation.model_output import SIRModelOutput

# %%
N = 10000
model = SIRModel(N)
beta = 0.0001
gamma = 0.1 
init_inf_frac = 0.05
model.simulate(beta, gamma, init_inf_frac, init_rec_frac=0, tmax=60)

# %%
plt.plot(model.result.I)
